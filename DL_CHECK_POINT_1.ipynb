# %% [markdown]
# <a href="https://colab.research.google.com/github/Soumiak/FASHION_MNSIT/blob/main/DL_CHECK_POINT_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
# In this practical, we implement and train a feed-forward neural network (also known as an "MLP" for "multi-layer perceptron") on a dataset called "Fashion MNIST", consisting of small greyscale images of items of fashion.

# %% [markdown]
# # Learning Objectives
#
# * Understand how to use Keras Layers to build a neural network architecture
# * Understand how a model is trained and evaluated
# * Understand the concept of train/validation/test split and why it's useful

# %%
# !pip install tensorflow-addons==0.16.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons==0.16.1
#   Downloading tensorflow_addons-0.16.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 14.2 MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow-addons==0.16.1) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.16.1

# %%
# !pip install keras
# !pin install RMSprop
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (2.8.0)
# /bin/bash: pin: command not found

# %%
from __future__ import print_function

import keras
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout,Flatten
from tensorflow.keras.optimizers import RMSprop
from keras.models import Sequential
from keras.layers import Dense, Dropout,Flatten
from tensorflow.keras.utils import to_categorical
import tensorflow_addons as tf
import numpy as np 
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_addons as tfa

# %% [markdown]
# # Data
# In this practical, we use the Fashion MNIST dataset consisting of 70,000 greyscale images and their labels. The dataset is divided
#  into 60,000 training images and 10,000 test images. The idea is to train a **classifier** to identify the class value (what type of fashion item it is) given the image. We train and *tune* a model on the 60,000 training images and then evaluate how well it classifies the 10,000 test images that the model did not see during training. This task is an example of a **supervised learning** problem, where we are given both input and labels (targets) to learn from. This is in contrast to **unsupervised learning** where we only have inputs from which to learn patterns or **reinforcement learning** where an agent learns how to maximise a reward signal through interaction with its environment.

# %% [markdown]
# ![Texte alternatif…](https://res.cloudinary.com/practicaldev/image/fetch/s---fNWEeWA--/c_imagga_scale,f_auto,fl_progressive,h_420,q_auto,w_1000/https://raw.githubusercontent.com/zalandoresearch/fashion-mnist/master/doc/img/fashion-mnist-sprite.png)

# %% [markdown]
# # Train/Validation/Test Split
#
# When we build machine learning models, the goal is to build a model that will perform well on future data that we have not seen yet. We say that we want our models to be able to generalise well from whatever training data we can collect and do have available, to whatever data we will be applying them to in future. To do this, we split whatever data we have available into a training set, a validation set and a test set. The idea is that we train our model and use the performance on the validation set to make any adjustments to the model and its hyperparameters, but then we report the final accuracy on the test set. The test set (which we never train on), therefore acts as a proxy for our future data.

# %%
(train_and_validation_images, train_and_validation_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step

# %%
train_and_validation_images.shape
# Out:
# (60000, 28, 28)

# %%
train_and_validation_labels.shape
# Out:
# (60000,)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
# Construct a validation set from the last 10000 images and labels from 
# train_and_validation_images and train_and_validation_labels
validation_images = train_and_validation_images[-10000:, :, :]
validation_labels = train_and_validation_labels[-10000:]

# Construct a training set from the first 50000 images and labels.
train_images = train_and_validation_images[:50000, :, :]
train_labels = train_and_validation_labels[:50000]

# %%
train_images.shape[0]
# Out:
# 50000

# %%
validation_images.shape
# Out:
# (10000, 28, 28)

# %%
text_labels = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
plt.figure()
random_index = np.random.randint(0, len(train_images))
plt.imshow(train_images[random_index], cmap='gray')
plt.colorbar()
numerical_label = train_labels[random_index]
text_description = text_labels[numerical_label]
plt.title('True Class: {} ("{}")'.format(numerical_label, text_description))

plt.gca().grid(False)

# %%
# Another view, showing 50 randomly selected images at a time
plt.figure(figsize=(20,20))
for i in range(50):
    plt.subplot(5,10,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    
    img_index = np.random.randint(0, 50000)
    plt.imshow(train_images[img_index], cmap=plt.cm.gray)
    plt.xlabel(text_labels[train_labels[img_index]])

# %% [markdown]
# # Preprocess

# %%
# Flatten

train_images_flatten = train_images.reshape(train_images.shape[0], 784)
validation_images_flatten = validation_images.reshape(validation_images.shape[0],784)
test_images_flatten = test_images.reshape(test_images.shape[0],784)

# %%
# Normalize

train_images = train_images/255.
validation_images = validation_images/255
test_images = test_images/255

# %%
# convert class vectors to binary class matrices
train_labels_categ = keras.utils.np_utils.to_categorical(train_labels, 10)
validation_labels_categ =keras.utils.np_utils.to_categorical(validation_labels, 10)
test_labels_categ = keras.utils.np_utils.to_categorical(test_labels, 10)

# %% [markdown]
# # Train

# %%
batch_size = 128
num_classes = 10
epochs = 40

model = Sequential([
          Flatten(input_shape=(28,28)),
          Dense(128,activation='relu'),
          Dense(10,activation='softmax')

])

# End Code
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',metrics=["accuracy"
                                                           ,tfa.metrics.F1Score(
                                                           num_classes=10,
                                                           average='macro',
                                                           name='f1_score_macro'),
                                                           tfa.metrics.F1Score(
                                                           num_classes=10,
                                                           average='weighted',
                                                           name='f1_score_weighted')], optimizer='Adam')
history = model.fit(train_images, train_labels_categ,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(validation_images, validation_labels_categ))
# Out:
# Epoch 1/40
# 391/391 [==============================] - 3s 4ms/step - loss: 0.5788 - accuracy: 0.8017 - f1_score_macro: 0.7993 - f1_score_weighted: 0.7994 - val_loss: 0.4511 - val_accuracy: 0.8443 - val_f1_score_macro: 0.8434 - val_f1_score_weighted: 0.8428
# Epoch 2/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.4153 - accuracy: 0.8544 - f1_score_macro: 0.8534 - f1_score_weighted: 0.8535 - val_loss: 0.4018 - val_accuracy: 0.8614 - val_f1_score_macro: 0.8594 - val_f1_score_weighted: 0.8590
# Epoch 3/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.3758 - accuracy: 0.8677 - f1_score_macro: 0.8669 - f1_score_weighted: 0.8670 - val_loss: 0.4407 - val_accuracy: 0.8461 - val_f1_score_macro: 0.8454 - val_f1_score_weighted: 0.8447
# Epoch 4/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.3474 - accuracy: 0.8739 - f1_score_macro: 0.8733 - f1_score_weighted: 0.8734 - val_loss: 0.3674 - val_accuracy: 0.8721 - val_f1_score_macro: 0.8700 - val_f1_score_weighted: 0.8697
# Epoch 5/40
# 391/391 [==============================] - 1s 4ms/step - loss: 0.3260 - accuracy: 0.8822 - f1_score_macro: 0.8817 - f1_score_weighted: 0.8818 - val_loss: 0.3615 - val_accuracy: 0.8715 - val_f1_score_macro: 0.8712 - val_f1_score_weighted: 0.8705
# Epoch 6/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.3077 - accuracy: 0.8886 - f1_score_macro: 0.8881 - f1_score_weighted: 0.8882 - val_loss: 0.3634 - val_accuracy: 0.8716 - val_f1_score_macro: 0.8726 - val_f1_score_weighted: 0.8721
# Epoch 7/40
# 391/391 [==============================] - 2s 5ms/step - loss: 0.2941 - accuracy: 0.8939 - f1_score_macro: 0.8934 - f1_score_weighted: 0.8935 - val_loss: 0.3351 - val_accuracy: 0.8831 - val_f1_score_macro: 0.8834 - val_f1_score_weighted: 0.8830
# Epoch 8/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2840 - accuracy: 0.8972 - f1_score_macro: 0.8968 - f1_score_weighted: 0.8969 - val_loss: 0.3481 - val_accuracy: 0.8773 - val_f1_score_macro: 0.8736 - val_f1_score_weighted: 0.8734
# Epoch 9/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2692 - accuracy: 0.9025 - f1_score_macro: 0.9021 - f1_score_weighted: 0.9022 - val_loss: 0.3284 - val_accuracy: 0.8848 - val_f1_score_macro: 0.8863 - val_f1_score_weighted: 0.8858
# Epoch 10/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2638 - accuracy: 0.9044 - f1_score_macro: 0.9040 - f1_score_weighted: 0.9041 - val_loss: 0.3287 - val_accuracy: 0.8843 - val_f1_score_macro: 0.8854 - val_f1_score_weighted: 0.8849
# Epoch 11/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2509 - accuracy: 0.9087 - f1_score_macro: 0.9084 - f1_score_weighted: 0.9085 - val_loss: 0.3199 - val_accuracy: 0.8866 - val_f1_score_macro: 0.8853 - val_f1_score_weighted: 0.8849
# Epoch 12/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2449 - accuracy: 0.9100 - f1_score_macro: 0.9097 - f1_score_weighted: 0.9098 - val_loss: 0.3164 - val_accuracy: 0.8880 - val_f1_score_macro: 0.8882 - val_f1_score_weighted: 0.8878
# Epoch 13/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2385 - accuracy: 0.9118 - f1_score_macro: 0.9115 - f1_score_weighted: 0.9116 - val_loss: 0.3201 - val_accuracy: 0.8870 - val_f1_score_macro: 0.8870 - val_f1_score_weighted: 0.8866
# Epoch 14/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2312 - accuracy: 0.9156 - f1_score_macro: 0.9152 - f1_score_weighted: 0.9153 - val_loss: 0.3119 - val_accuracy: 0.8897 - val_f1_score_macro: 0.8892 - val_f1_score_weighted: 0.8888
# Epoch 15/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2261 - accuracy: 0.9174 - f1_score_macro: 0.9171 - f1_score_weighted: 0.9172 - val_loss: 0.3171 - val_accuracy: 0.8905 - val_f1_score_macro: 0.8911 - val_f1_score_weighted: 0.8907
# Epoch 16/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2202 - accuracy: 0.9183 - f1_score_macro: 0.9180 - f1_score_weighted: 0.9181 - val_loss: 0.3192 - val_accuracy: 0.8878 - val_f1_score_macro: 0.8887 - val_f1_score_weighted: 0.8883
# Epoch 17/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2132 - accuracy: 0.9210 - f1_score_macro: 0.9207 - f1_score_weighted: 0.9208 - val_loss: 0.3361 - val_accuracy: 0.8841 - val_f1_score_macro: 0.8855 - val_f1_score_weighted: 0.8851
# Epoch 18/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2067 - accuracy: 0.9248 - f1_score_macro: 0.9245 - f1_score_weighted: 0.9246 - val_loss: 0.3234 - val_accuracy: 0.8848 - val_f1_score_macro: 0.8864 - val_f1_score_weighted: 0.8858
# Epoch 19/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.2028 - accuracy: 0.9258 - f1_score_macro: 0.9255 - f1_score_weighted: 0.9256 - val_loss: 0.3273 - val_accuracy: 0.8856 - val_f1_score_macro: 0.8841 - val_f1_score_weighted: 0.8837
# Epoch 20/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1982 - accuracy: 0.9270 - f1_score_macro: 0.9267 - f1_score_weighted: 0.9268 - val_loss: 0.3191 - val_accuracy: 0.8923 - val_f1_score_macro: 0.8932 - val_f1_score_weighted: 0.8927
# Epoch 21/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1902 - accuracy: 0.9302 - f1_score_macro: 0.9300 - f1_score_weighted: 0.9301 - val_loss: 0.3225 - val_accuracy: 0.8883 - val_f1_score_macro: 0.8893 - val_f1_score_weighted: 0.8887
# Epoch 22/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1856 - accuracy: 0.9325 - f1_score_macro: 0.9323 - f1_score_weighted: 0.9324 - val_loss: 0.3243 - val_accuracy: 0.8875 - val_f1_score_macro: 0.8869 - val_f1_score_weighted: 0.8866
# Epoch 23/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1804 - accuracy: 0.9335 - f1_score_macro: 0.9333 - f1_score_weighted: 0.9334 - val_loss: 0.3444 - val_accuracy: 0.8841 - val_f1_score_macro: 0.8834 - val_f1_score_weighted: 0.8829
# Epoch 24/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1778 - accuracy: 0.9348 - f1_score_macro: 0.9346 - f1_score_weighted: 0.9347 - val_loss: 0.3392 - val_accuracy: 0.8876 - val_f1_score_macro: 0.8876 - val_f1_score_weighted: 0.8871
# Epoch 25/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1775 - accuracy: 0.9350 - f1_score_macro: 0.9347 - f1_score_weighted: 0.9348 - val_loss: 0.3345 - val_accuracy: 0.8895 - val_f1_score_macro: 0.8885 - val_f1_score_weighted: 0.8881
# Epoch 26/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1674 - accuracy: 0.9397 - f1_score_macro: 0.9395 - f1_score_weighted: 0.9396 - val_loss: 0.3310 - val_accuracy: 0.8911 - val_f1_score_macro: 0.8911 - val_f1_score_weighted: 0.8907
# Epoch 27/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1663 - accuracy: 0.9387 - f1_score_macro: 0.9384 - f1_score_weighted: 0.9385 - val_loss: 0.3424 - val_accuracy: 0.8892 - val_f1_score_macro: 0.8905 - val_f1_score_weighted: 0.8899
# Epoch 28/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1633 - accuracy: 0.9403 - f1_score_macro: 0.9401 - f1_score_weighted: 0.9402 - val_loss: 0.3394 - val_accuracy: 0.8892 - val_f1_score_macro: 0.8893 - val_f1_score_weighted: 0.8889
# Epoch 29/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1570 - accuracy: 0.9427 - f1_score_macro: 0.9425 - f1_score_weighted: 0.9426 - val_loss: 0.3436 - val_accuracy: 0.8869 - val_f1_score_macro: 0.8870 - val_f1_score_weighted: 0.8865
# Epoch 30/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1562 - accuracy: 0.9424 - f1_score_macro: 0.9422 - f1_score_weighted: 0.9423 - val_loss: 0.3379 - val_accuracy: 0.8942 - val_f1_score_macro: 0.8946 - val_f1_score_weighted: 0.8941
# Epoch 31/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1502 - accuracy: 0.9457 - f1_score_macro: 0.9455 - f1_score_weighted: 0.9456 - val_loss: 0.3572 - val_accuracy: 0.8869 - val_f1_score_macro: 0.8861 - val_f1_score_weighted: 0.8858
# Epoch 32/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1480 - accuracy: 0.9465 - f1_score_macro: 0.9464 - f1_score_weighted: 0.9464 - val_loss: 0.3582 - val_accuracy: 0.8896 - val_f1_score_macro: 0.8904 - val_f1_score_weighted: 0.8899
# Epoch 33/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1409 - accuracy: 0.9486 - f1_score_macro: 0.9484 - f1_score_weighted: 0.9485 - val_loss: 0.3455 - val_accuracy: 0.8896 - val_f1_score_macro: 0.8905 - val_f1_score_weighted: 0.8900
# Epoch 34/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1424 - accuracy: 0.9486 - f1_score_macro: 0.9485 - f1_score_weighted: 0.9486 - val_loss: 0.3547 - val_accuracy: 0.8922 - val_f1_score_macro: 0.8933 - val_f1_score_weighted: 0.8928
# Epoch 35/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1393 - accuracy: 0.9495 - f1_score_macro: 0.9494 - f1_score_weighted: 0.9495 - val_loss: 0.3611 - val_accuracy: 0.8910 - val_f1_score_macro: 0.8907 - val_f1_score_weighted: 0.8903
# Epoch 36/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1345 - accuracy: 0.9509 - f1_score_macro: 0.9508 - f1_score_weighted: 0.9508 - val_loss: 0.3681 - val_accuracy: 0.8911 - val_f1_score_macro: 0.8919 - val_f1_score_weighted: 0.8914
# Epoch 37/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1317 - accuracy: 0.9523 - f1_score_macro: 0.9521 - f1_score_weighted: 0.9522 - val_loss: 0.3582 - val_accuracy: 0.8894 - val_f1_score_macro: 0.8899 - val_f1_score_weighted: 0.8895
# Epoch 38/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1297 - accuracy: 0.9534 - f1_score_macro: 0.9533 - f1_score_weighted: 0.9534 - val_loss: 0.3725 - val_accuracy: 0.8898 - val_f1_score_macro: 0.8901 - val_f1_score_weighted: 0.8896
# Epoch 39/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1288 - accuracy: 0.9532 - f1_score_macro: 0.9531 - f1_score_weighted: 0.9532 - val_loss: 0.3874 - val_accuracy: 0.8860 - val_f1_score_macro: 0.8842 - val_f1_score_weighted: 0.8839
# Epoch 40/40
# 391/391 [==============================] - 1s 3ms/step - loss: 0.1242 - accuracy: 0.9555 - f1_score_macro: 0.9554 - f1_score_weighted: 0.9555 - val_loss: 0.3841 - val_accuracy: 0.8868 - val_f1_score_macro: 0.8849 - val_f1_score_weighted: 0.8846

# %% [markdown]
# # Test

# %%
score = model.evaluate(test_images, test_labels_categ, verbose=0)
print('Test accuracy:', score[1])
# You should be able to get,at least, 88% accuracy
# Out:
# Test accuracy: 0.8809000253677368

# %%
test_logits = model.predict(test_images)

# %%
test_logits
# Out:
# array([[8.15983078e-13, 1.73604056e-12, 2.89739410e-09, ...,
#         1.35975628e-04, 3.61603081e-09, 9.99851465e-01],
#        [7.49867249e-05, 1.46322417e-14, 9.99860764e-01, ...,
#         1.06435145e-13, 3.33418432e-10, 2.58781309e-19],
#        [3.96504010e-11, 1.00000000e+00, 9.36934341e-13, ...,
#         1.90764095e-28, 3.14158689e-18, 7.59607339e-27],
#        ...,
#        [8.24289614e-08, 3.29326545e-14, 4.76281681e-10, ...,
#         8.65695276e-12, 9.99999881e-01, 3.75227608e-19],
#        [4.12110172e-11, 9.99999881e-01, 2.06185919e-11, ...,
#         1.45158797e-14, 1.11215621e-14, 3.45563388e-14],
#        [1.31851712e-08, 8.26132140e-09, 1.15686603e-07, ...,
#         1.03638573e-04, 8.49463447e-07, 1.01095615e-07]], dtype=float32)

# %%
test_predictions = np.argmax(test_logits, axis=1)

# %%
test_predictions
# Out:
# array([9, 2, 1, ..., 8, 1, 5])

# %%
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid('off')
    
    img_index = np.random.randint(0, 1000)
    plt.imshow(test_images[img_index], cmap=plt.cm.gray)
    actual_label  = np.argmax(test_labels_categ[img_index])
    predicted_label = np.argmax(test_logits[img_index])
    
    plt.xlabel("Actual: {} ({})\n Predicted: {} ({})".format(
        actual_label, text_labels[actual_label], predicted_label, text_labels[predicted_label]
    ))
    
plt.tight_layout()
plt.show()
